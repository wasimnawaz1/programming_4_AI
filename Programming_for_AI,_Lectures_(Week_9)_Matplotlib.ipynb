# %% [markdown]
# <a href="https://colab.research.google.com/github/wasimnawaz1/programming_4_AI/blob/main/Programming_for_AI%2C_Lectures_(Week_9)_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 9: Introduction to **AI271 Programming for AI**
#
# ### **Link to find the lecture:**
# https://github.com/wasimnawaz1/programming_4_AI

# %% [markdown]
# ### **Matplotlib** Library: Visualizing Data
# As the saying goes, *A picture is worth a thousand numbers*, and visualizing your data is crucial for understanding it and getting insights.
#
# Matplotlib is the foundation for creating plots and visualizations in Python and to perform **Exploratory Data Analysis (EDA)**.
#
# - **Exploratory Data Analysis (EDA)** is a process to get familiar with the structure and important features of a dataset.

# %% [markdown]
# ### Line Plot
#
# **Line plots** are predominantly useful for conveying changes over space or time. They are mostly used to plot data along a scale divided into equal intervals, e.g., time.
#
# - To generate a line plot: use `plt.plot(x, y, label=...)`
# - Add titles and labels using `plt.title()`, `plt.xlabel()`, `plt.ylabel()`
# - Add a legend using `plt.legend()`
# - Multiple plots can be drawn on the same figure

# %%
import matplotlib.pyplot as plt

x1 = [1,2,3,4]
y1 = [2,4,3,5]
plt.plot(x1, y1, label = "line 1")
plt.legend()
plt.show()

# %%
x1 = [1,2,3]
y1 = [2,4,1]
plt.plot(x1, y1, label = "line 1")
# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')
# giving a title to my graph
plt.title('My first line plot')
plt.legend()
plt.show()

# %%
# Generating x and y points to plot
import numpy as np
import matplotlib.pyplot as plt
x1= np.arange(0, 10*(np.pi), 0.1)
y1 = np.cos(x1) # cosine function from Numpy library


# potting the points
plt.plot(x1, y1, label = 'cosine')
plt.xlabel('Angle') # naming the x axis
plt.ylabel('Amplitude') # naming the y axis

# Generating x and y points for the second plot
x2= np.arange(0, 10*(np.pi), 0.1)
y2 = np.cos(x2)*0.1*np.arange(10*(np.pi),0,-0.1)
##       cosine*0.1* decreasing function

# decaying cosine function
# potting the points
plt.plot(x2, y2, label = 'Decaying cosine')
plt.legend() # show a legend on the plot
plt.title('Two functions on the same graph') # gives a title to the plot
plt.show() # shows the graph, and removes the text output.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Path to dataset: https://www.kaggle.com/datasets/aariyan101/usa-housingcsv
# !kaggle datasets download -d aariyan101/usa-housingcsv --unzip          # direct download to /content folder

# Load the dataset first
housing_price = pd.read_csv('/content/USA_Housing.csv')
housing_price

# %%
# Create a figure with a specific size (width, height in inches).
plt.figure(figsize=(7, 5))

# Plotting Avg. Area Income vs Price
plt.plot(housing_price['Avg. Area Income'].iloc[::50],
        housing_price['Price'].iloc[::50], color='green', marker='*')

# Giving title and label names
plt.title('Avg. Area Income Vs Price', fontsize=14)
plt.xlabel('Avg. Area Income', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Line Plot

# **Creating a Simple Sine Wave Plot**

# data for plotting
x_values = np.linspace(0, 10, 100)  # 100 points from 0 to 10   (evenly spaced numbers over a specified interval)
y_values = np.sin(x_values)        # Sine of each x value

# Create a figure with a specific size (width, height in inches).
plt.figure(figsize=(8, 6))

# Plot the data: `plt.plot()` connects the points with lines.
plt.plot(x_values, y_values)

# Add a title to the plot.
plt.title('A Simple Sine Wave Plot')

# Label the x-axis.
plt.xlabel('X-axis')

# Label the y-axis.
plt.ylabel('Y-axis')

# Add a grid for better readability.
plt.grid(True)

# Display the plot. This command is essential to render the plot when running
# scripts or in some interactive environments.
plt.show()

# %% [markdown]
# ### Scatter Plot
#
# A **scatter plot** is used to visualize any two variables from a dataset in two dimensions. It uses dots or marks to plot values of two variables.
#
# Scatter plots help us observe:
# - **Positive linear relationship**: increase in one variable causes increase in the other
# - **Negative linear relationship**: increase in one variable causes decrease in the other
#
# If the dots are **color-coded**, additional variables can be shown in two dimensions.
#
# Use `plt.rcParams['figure.figsize']` to control the plot size for better readability.
#
# Matplotlib's `rcParams` (runtime configuration parameters) are dictionary-like settings that control default visual styles (colors, fonts, sizes) for plots, allowing for consistent styling without repeating code.

# %%
# Adjusting the figure size using rcParams function
plt.rcParams['figure.figsize'] = [8,6]
# Scatter plot
plt.scatter(housing_price['Avg. Area Income'].iloc[::10],
            housing_price['Price'].iloc[::10], color='red', marker='+')
# Giving title and label names
plt.title('Avg. Area Income Vs Price', fontsize=14)
plt.xlabel('Avg. Area Income', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
# Scatter Plot --- Example
# Let's create some dummy data for a scatter plot to show a relationship
# np.random.seed(42) # for reproducibility
student_hours = np.random.randint(1, 10, 15) # Hours studied
student_scores = 50 + student_hours * 5 + np.random.randn(15) * 5 # Corresponding scores

plt.figure(figsize=(7, 5))
plt.scatter(student_hours, student_scores, color='green', alpha=0.8)
plt.title('Study Hours vs. Exam Scores')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Path to dataset: https://www.kaggle.com/datasets/aariyan101/usa-housingcsv

# Load the dataset first
housing_price = pd.read_csv('/content/drive/My Drive/USA_Housing.csv')

# Create a figure with a specific size (width, height in inches).
plt.figure(figsize=(10, 10))

# Plotting Avg. Area Income vs Price
plt.scatter(housing_price['Avg. Area Income'],                                #.iloc[::100]
            housing_price['Price'], color='red', marker='.')

# Giving title and label names
plt.title('Avg. Area Income Vs Price', fontsize=14)
plt.xlabel('Avg. Area Income', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
# Example: Plotting two variables from our DataFrame
plt.figure(figsize=(10, 7))
# Scatter plot
plt.scatter(housing_price['Avg. Area Income'],
            housing_price['Price'], color='red', marker='o', label = 'Avg. Area Income')

# Scatter plot
plt.scatter(housing_price['Area Population'],
            housing_price['Price'], color='blue', marker='x', label = 'Area Population')

# Giving title and label names
plt.title('Avg. Area Income Vs Price', fontsize=20)
plt.xlabel('Avg. Area Income (Red), Area Population (blue)', fontsize=20)
plt.ylabel('Price', fontsize=20)
plt.legend(fontsize=20)
plt.grid(True)

# %% [markdown]
# ### Bar Chart
#
# **Bar charts** are used when we have **categorical or discrete data** that can take one of a small set of values.
#
# - The lengths of rectangular bars are proportional to the values they represent
# - Suitable for visualizing species counts, categorical distributions, etc.
# - We use the **Iris dataset** here, which contains three iris flower species.
# - `bar` plots vertical bars, whereas `barh` plots horizontal bars.
# The Iris dataset can be downloaded from Kaggle or from `sklearn` library.

# %%
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()   # 3 target variables / categories / classes of iris flowers
iris_data = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_data['species'] = iris.target  # Adds the target labels
iris_data.info()
iris_data

# %%
# Generating a bar chart
plt.barh(iris_data['species'], iris_data['sepal width (cm)'])

# Giving title and label names
plt.title('Sepal Length (cm) Vs Species', fontsize=14)
plt.xlabel('Species', fontsize=14)
plt.ylabel('Sepal Length (cm)', fontsize=14)
plt.show()

# %%
# Generating a bar chart
plt.bar(iris_data['species'], iris_data['sepal length (cm)'], label = 'Sepal Length (cm)')
plt.bar(iris_data['species'], iris_data['sepal width (cm)'], label = 'Sepal Width (cm)', color='green')
# Giving title and label names
plt.title('Sepal Length (cm) and With (cm) Vs Species', fontsize=14)
plt.xlabel('Species', fontsize=14)
plt.ylabel('Sepal Length (cm) and Width (cm)', fontsize=14)
plt.legend()
plt.show()

# %%
import numpy as np
species_names = iris_data['species'].unique()

x = np.arange(len(species_names))
w = 0.4
plt.figure(figsize=(10, 6))
plt.bar(iris_data['species'] - w/2, iris_data['sepal length (cm)'], w, label='Sepal Length')     # plt.bar(x, y or height, width)
plt.bar(iris_data['species'] + w/2, iris_data['sepal width (cm)'], w, label='Sepal Width', color='green')

plt.xticks(iris_data['species'])

plt.title('Sepal Length (cm) Vs Species', fontsize=14)
plt.xlabel('Species', fontsize=14)
plt.ylabel('Sepal Length (cm)', fontsize=14)

plt.legend()
plt.show()

# %%
# Bar Chart --- Another Example

# Example: Showing categorical data counts
import pandas as pd

# Create a sample DataFrame for demonstration purposes
data = {'City': ['New York', 'Los Angeles', 'New York', 'Chicago', 'Los Angeles', 'New York', 'Chicago', 'Houston', 'Los Angeles', 'New York']}
df = pd.DataFrame(data)

city_counts = df['City'].value_counts()
print("\nCity Counts for Bar Chart:")
print(city_counts)

plt.figure(figsize=(7, 5))
plt.bar(city_counts.index, city_counts.values, color=['blue', 'red', 'green', 'black'])       # try barh instead of bar
plt.title('Number of People by City')
plt.xlabel('City')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--')
plt.show()

city_counts
# Out:
# City Counts for Bar Chart:
# City
# New York       4
# Los Angeles    3
# Chicago        2
# Houston        1
# Name: count, dtype: int64
# City
# New York       4
# Los Angeles    3
# Chicago        2
# Houston        1
# Name: count, dtype: int64

# %% [markdown]
# ### Box Plots
#
# A **box plot** (also called a box and whisker plot) displays the summary of a dataset as **five numbers**:
#
# 1. The **minimum value** (excluding outliers)
# 2. The **first quartile** (Q1)
# 3. The **second quartile / median** (Q2)
# 4. The **third quartile** (Q3)
# 5. The **maximum value** (excluding outliers)
#
# ![image.png](data:image/png;base64,...)
#
# Outliers are shown beyond the minimum and maximum points (the whiskers).
#
# Box plots can be generated using **Matplotlib**, **Pandas**, or **Seaborn**.

# %%
import matplotlib.pyplot as plt
plt.boxplot([0, 1, 10, 15, 4, -6, -15 -2, 30, 35, -20, 11])
plt.grid()
plt.show()

# %%
import numpy as np
import pandas as pd

myframe = pd.DataFrame(np.random.randn(1000, 3),
columns=['Col1', 'Col2', 'Col3'])
# print(myframe)
boxplot = myframe.boxplot(column=['Col1', 'Col2', 'Col3'])

# %% [markdown]
# ### Histogram
#
# A **histogram** is a plot that shows the **frequency distribution or shape** of a numeric feature in a dataset.
#
# - Allows us to discover the **underlying distribution** of the data by visual inspection
# - Use `plt.hist()` and pass a collection of numeric values
# - By default, `hist()` uses **10 bins** to group the data
# - The number of bins can be changed using the `bins` option
# - A bell-shaped histogram indicates a **Normal / Gaussian distribution** — important because many AI/ML algorithms assume this assumption.

# %%
# Path to dataset: https://www.kaggle.com/datasets/aariyan101/usa-housingcsv
# !kaggle datasets download -d aariyan101/usa-housingcsv --unzip          # direct download to /content folder

# Load the dataset first
housing_price = pd.read_csv('/content/USA_Housing.csv')
plt.hist(housing_price['Price'], bins = 50)

plt.show()

print(housing_price['Price'].describe())
# Out:
# count    5.000000e+03
# mean     1.232073e+06
# std      3.531176e+05
# min      1.593866e+04
# 25%      9.975771e+05
# 50%      1.232669e+06
# 75%      1.471210e+06
# max      2.469066e+06
# Name: Price, dtype: float64

# %%
plt.hist(housing_price['Price'], bins = 5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create some dummy data of size 100
dummy_data = (10*np.random.randn(10000)+5)

# Plot its histogram
plt.hist(dummy_data, bins=100)
plt.title('Histogram of Dummy Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Pie Charts
#
# A **pie chart** is a circular statistical chart used to display the **percentage distribution of categorical variables**.
#
# - The area of the whole chart represents **100%** of the data
# - Each slice's area represents the **percentage share** of a category
# - Popular in business communications: summarizing sales, operations, resource usage, survey results, etc.
# - Use `plt.pie()` from the pyplot module
# - `autopct='%1.1f%%'` controls the formatting of percentage labels

# %%
cont_pop = {'Asia': 4641054775, 'Africa':1340598147,
'Europe': 747636026, 'North America': 592072212,'South America': 430759766,
'Australia/Oceania': 42677813}

# Generating a pie plot
plt.pie(cont_pop.values(),
labels=cont_pop.keys(), autopct='%.2f%%')    # using `autopct` (automatic percentage) parameter
plt.show()

# %% [markdown]
# ### Testing Assumptions about Data
#
# Statistical, AI, and ML models work best when data satisfies certain **assumptions**:
#
# - **Independence of features** — features should not be correlated with each other
# - **Linear or quadratic dependency** of features with the target variable
# - **Normal / Gaussian distribution** of features
#
# One main objective of EDA is to **test these assumptions** before applying machine learning.
#
# We use the following Pandas functions to understand the dataset:
# - `head()` — first 5 rows
# - `tail()` — last 5 rows
# - `shape` — dimensions of the dataset
# - `info()` — column types and null counts
# - `describe()` — summary statistics
# - `isnull().sum()` — count of missing values per column

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Path to dataset: https://www.kaggle.com/datasets/aariyan101/usa-housingcsv
# !kaggle datasets download -d aariyan101/usa-housingcsv --unzip          # direct download to /content folder

# Load the dataset first
housing_price = pd.read_csv('/content/USA_Housing.csv')

print(housing_price.head())
print(housing_price.tail())

print(housing_price.shape)
print(housing_price.info())
print(housing_price.describe())
print(housing_price.isnull().sum())
# Out:
# Dataset URL: https://www.kaggle.com/datasets/aariyan101/usa-housingcsv
# License(s): unknown
# ...
# 100% 363k/363k [00:00<00:00, 608kB/s]
#
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
# ...

# %% [markdown]
# ### Checking Assumption: Normal Distribution of Features
#
# Many machine learning models **assume a Normal / Gaussian distribution** of features.
#
# We can check whether features are normally distributed by **plotting histograms** of each feature.
#
# A **bell-shaped** histogram indicates a Gaussian distribution — desirable for most ML algorithms.

# %%
# Plotting histogram of all the features
plt.hist(housing_price['Avg. Area Income'], bins = 20, label = 'Avg. Area Income')
plt.legend()
plt.show()

plt.hist(housing_price['Avg. Area House Age'], bins = 20, label ='Avg. Area House Age')
plt.legend()
plt.show()

plt.hist(housing_price['Avg. Area Number of Rooms'], bins = 20, label = 'Avg. Area Number of Rooms')
plt.legend()
plt.show()

plt.hist(housing_price['Avg. Area Number of Bedrooms'], bins = 20, label = 'Avg. Area Number of Bedrooms')
plt.legend()
plt.show()

plt.hist(housing_price['Area Population'], bins = 20, label = 'Area Population')
plt.legend()
plt.show()

# %% [markdown]
# ### Checking Assumption: Independence of Features
#
# We can check if features are **independent of each other** using a **scatter matrix**:
#
# - **Diagonal entries**: histograms (or KDE plots) of each individual feature
# - **Off-diagonal entries**: scatter plots of every pair of features
#
# Interpretation:
# - Points forming a **circle** → features are **independent**
# - Points forming an **angled oval** → features are **dependent**
#
# The `diagonal` option can be set to `'kde'` (kernel density estimation) or `'hist'`.

# %%
### Using pandas scatter_matrix function

from pandas.plotting import scatter_matrix
scatter_matrix(housing_price, figsize=(10, 10), diagonal='kde')       # use diagonal='kde' for smooth kernel density estimation curve
plt.show()

# %%
scatter_matrix?

# %%
# Create scatter matrix with different fontsizes
axes = scatter_matrix(
    housing_price,
    figsize=(12,12),
    diagonal='hist'
)

# Customize fontsize of x and y ticks/labels
for ax in axes.flatten():        # coverts multi-dimensional axes data into 1-d data

    # X-axis tick fontsize
    ax.xaxis.label.set_size(8)
    ax.yaxis.label.set_size(8)

    # Tick fontsize
    ax.tick_params(axis='x', labelsize=8)
    ax.tick_params(axis='y', labelsize=8)

plt.show()

# %% [markdown]
# ### Selecting Important Features / Variables
#
# **Feature selection** picks features that contribute most to the target variable. It helps:
# - Reduce **computational load**
# - Achieve **better accuracy**
# - Remove irrelevant or less important features
#
# ### Correlation-Based Feature Selection
#
# **Correlation** is a statistical term that measures the dependency between two features as a number ranging from **–1 to 1**:
#
# - **Positive correlation**: both variables increase/decrease together
# - **Negative correlation**: one increases while the other decreases
# - **Near zero**: features are nearly independent
#
# We use:
# - `corr()` method to compute the correlation matrix
# - `sns.heatmap()` from Seaborn to visualize it
#
# Features with a **small correlation** to the target variable can be dropped.

# %%
housing_price
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
### Check the correlation of each feature with target variable `price`
### Features with a **small correlation** to the target variable can be dropped
### (e.g., `Avg. Area Number of Bedrooms` has correlation 0.17 with `Price`).

import seaborn as sns

# Drop the 'Address' column before calculating correlation as it is a string column.
housing_price_numeric = housing_price.drop(columns=['Address'])

corrmat = housing_price_numeric.corr()   # pandas corr() function applied to a DataFrame
plt.figure(figsize=(8, 8))

sns.heatmap(housing_price_numeric.corr(), # correlation matrix as heatmap
            annot=True,
            cmap="RdYlGn")
            # cmap="viridis")
plt.show()

# %%
feature_ind = corrmat.index
feature_ind
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price'],
#       dtype='object')

# %% [markdown]
# ### Exercise Questions
#
# Q1. Create a Matplotlib line plot for a NumPy array.
#
# Q2. Plot multiple lines on same graph using different styles and labels.
#
# Q3. Create a bar chart from DataFrame values.
#
# Q4. Plot histogram of random numbers using NumPy.
#
# Q5. Create scatter plot using two NumPy arrays.
#
# Q6. Use loop to generate multiple plots in one figure.
#
# Q7. Plot DataFrame columns directly using df.plot().
#
# Q8. Customize plot with title, labels, legend, and grid.
#
# Q9. Combine NumPy + Pandas:
#      - create array → convert to DataFrame → plot it.
#
# Q10. Build mini analysis pipeline:
#      - create random data
#      - store in DataFrame
#      - filter values
#      - compute stats
#      - visualize results
#
#
# Q11. To create a legend in a line plot, we specify the value of which parameter?
# - A) axis &nbsp;&nbsp; B) label &nbsp;&nbsp; C) title &nbsp;&nbsp; D) Any of the above
#
# Q12. Increasing the number of bins ___________ the histogram.
# - A) Expands &nbsp;&nbsp; B) Contracts &nbsp;&nbsp; C) Smooths &nbsp;&nbsp; D) Roughens
#
# Q13. `plt.plot()` generates a:
# - A) Scatter plot &nbsp;&nbsp; B) Line plot &nbsp;&nbsp; C) Pie plot &nbsp;&nbsp; D) Any of the above
#
# Q14. To check the frequency distribution or shape of a dataset, we generate a:
# - A) Bar plot &nbsp;&nbsp; B) Pie plot &nbsp;&nbsp; C) Histogram &nbsp;&nbsp; D) Any of the above
#
# Q15. Which plot can be used for multivariate visualization?
# - A) Line plot &nbsp;&nbsp; B) Scatter plot &nbsp;&nbsp; C) Scatter matrix &nbsp;&nbsp; D) All of the above

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})

# Q1
arr = np.arange(10)
plt.figure()
plt.plot(arr)
plt.title("Q1 Line Plot")
plt.show()

# Q2
plt.figure()
plt.plot(arr, label='line1')
plt.plot(arr*2, label='line2')
plt.legend()
plt.show()

# Q3
df.plot(kind='bar')
plt.title("Q3 Bar Chart")
plt.show()

# Q4
plt.hist(np.random.randn(100))
plt.title("Q4 Histogram")
plt.show()

# Q5
x = np.arange(10)
y = x**2
plt.scatter(x,y)
plt.title("Q5 Scatter")
plt.show()

# Q6
plt.figure()
for i in range(3):
    plt.plot(np.arange(10), np.arange(10)*(i+1))
plt.title("Q6 Multiple Lines")
plt.show()

# Q7
df.plot()
plt.title("Q7 DataFrame Plot")
plt.show()

# Q8
plt.figure()
plt.plot(x,y)
plt.title("Custom Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.show()

# Q9
arr = np.random.randint(1,10,(5,3))
df = pd.DataFrame(arr, columns=['A','B','C'])
df.plot()
plt.title("Q9 NumPy → Pandas → Plot")
plt.show()

# Q10
data = np.random.randint(1,100,20)
df = pd.DataFrame({'vals':data})
filtered = df[df['vals']>50]
print("Q10 Stats:", filtered.describe())
filtered.plot(kind='hist')
plt.show()

# %% [markdown]
# ### Homework Questions Related to Handling String Features

# %%
import pandas as pd

# Create a sample DataFrame with string columns
data = {
    'String_Numbers': ['10', '20', '30', '40', '50'],
    'String_Mixed': ['100', '200', 'not_a_number', '400', '500'],
    'Other_String': ['apple', 'banana', 'orange', 'grape', 'kiwi']
}
df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)
print("\nData types before conversion:")
print(df.dtypes)

# Convert 'String_Numbers' column to numeric
df['Numeric_Numbers'] = pd.to_numeric(df['String_Numbers'])

# Convert 'String_Mixed' column to numeric
df['Numeric_Mixed'] = pd.to_numeric(df['String_Mixed'], errors='coerce')         #, errors='coerce' forces errors to NaN

print("\nDataFrame after conversions:")
print(df)
print("\nData types after conversion:")
print(df.dtypes)

# Note: Columns like 'Other_String' containing non-numeric words cannot be
# directly converted to numeric.
# Out:
# Original DataFrame:
#   String_Numbers  String_Mixed Other_String
# 0             10           100        apple
# 1             20           200       banana
# 2             30  not_a_number       orange
# 3             40           400        grape
# 4             50           500         kiwi
#
# Data types before conversion:
# String_Numbers    object
# String_Mixed      object
# Other_String      object
# dtype: object
#
# DataFrame after conversions:
#   String_Numbers  String_Mixed Other_String  Numeric_Numbers  Numeric_Mixed
# 0             10           100        apple               10          100.0
# 1             20           200       banana               20          200.0
# 2             30  not_a_number       orange               30            NaN
# 3             40           400        grape               40          400.0
# 4             50           500         kiwi               50          500.0
#
# Data types after conversion:
# String_Numbers      object
# ...

# %%
# One-hot encoding creates new binary columns for each unique category.
# This is suitable for models that require numerical input.

import pandas as pd

# Create a sample DataFrame with a categorical string column
data = {
    'Product': ['Laptop', 'Mouse', 'Keyboard', 'Laptop', 'Mouse'],
    'Price': [1200, 25, 75, 1300, 30],
    'Color': ['Silver', 'Black', 'Black', 'Grey', 'Silver']
}
df_categorical = pd.DataFrame(data)

print("Original DataFrame with categorical data:")
print(df_categorical)
print("\nData types before one-hot encoding:")
print(df_categorical.dtypes)

# Perform one-hot encoding on the 'Product' and 'Color' columns
df_encoded = pd.get_dummies(df_categorical, columns=['Product', 'Color'], dtype=int)

print("\nDataFrame after one-hot encoding:")
print(df_encoded)
print("\nData types after one-hot encoding:")
print(df_encoded.dtypes)

# %%
# Note: Label Encoding is suitable for ordinal categorical data (where there's an inherent order)

import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Re-using the sample DataFrame with categorical string columns
data = {
    'Product': ['Laptop', 'Mouse', 'Keyboard', 'Laptop', 'Mouse'],
    'Price': [1200, 25, 75, 1300, 30],
    'Color': ['Silver', 'Black', 'Black', 'Grey', 'Silver']
}
df_categorical = pd.DataFrame(data)

print("Original DataFrame:")
print(df_categorical)

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to the 'Product' column
df_categorical['Product_Encoded'] = label_encoder.fit_transform(df_categorical['Product'])
print(f"\nMapping for Product: {list(label_encoder.classes_)} -> {list(range(len(label_encoder.classes_)))}")

# Apply LabelEncoder to the 'Color' column
df_categorical['Color_Encoded'] = label_encoder.fit_transform(df_categorical['Color'])
print(f"Mapping for Color: {list(label_encoder.classes_)} -> {list(range(len(label_encoder.classes_)))}")

print("\nDataFrame after Label Encoding:")
print(df_categorical)
print("\nData types after encoding:")
print(df_categorical.dtypes)

# %%
### Homework: Labeling Boxplot

### Use ? with a method to read its documentation, for example, plt.boxplot?

import matplotlib.pyplot as plt
import numpy as np

data = [0, 1, 10, 15, 4, -6, -15 -2, 30, 40, -20, 11]

plt.figure(figsize=(8, 6))
box_plot_dict = plt.boxplot(data, vert=True, patch_artist=True)   # horizontal / vertical orientation and filling of the box

plt.title('Box Plot of Sample Data with Quartile Labels')
plt.ylabel('Values')
plt.grid(True)

# Extracting and labeling quartiles and median
for i, line in enumerate(box_plot_dict['medians']):
    x, y = line.get_xydata()[0]
    median = line.get_ydata()[0]
    plt.text(x + 0.1, median, f'Median: {median:.2f}', va='center', color='black', fontsize=9)

for i, box in enumerate(box_plot_dict['boxes']):
    # Box contains 25th and 75th percentile (Q1 and Q3)
    # Accessing the y-coordinates from the PathPatch vertices
    y_coords = box.get_path().vertices[:, 1]
    q1 = np.min(y_coords) # Q1 is the minimum y-coordinate of the box
    q3 = np.max(y_coords) # Q3 is the maximum y-coordinate of the box

    # Get x-coordinate for text placement from the box's vertices
    x_coords = box.get_path().vertices[:, 0]
    x_position = np.min(x_coords) # Use the left-most x-coordinate of the box

    # Place labels slightly above/below the box edges
    plt.text(x_position - 0.1, q1, f'Q1: {q1:.2f}', va='center', ha='right', color='blue', fontsize=9)
    plt.text(x_position - 0.1, q3, f'Q3: {q3:.2f}', va='center', ha='right', color='blue', fontsize=9)

plt.tight_layout()
plt.show()
